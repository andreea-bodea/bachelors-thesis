# %% [markdown]
# **BERTopic Maarten Grootendorst**
#
# Installation with sentence-transformers
#
# 3 main algorithm components
# 1. Embed Documents: Extract document embeddings with Sentence Transformers
# 2. Cluster Documents: Create groups of similar documents with UMAP (to reduce the dimensionality of embeddings) and HDBSCAN (to identify and cluster semantically similar documents)
# 3. Create Topic Representation: Extract and reduce topics with c-TF-IDF   (class-based term frequency, inverse document frequency)

# %%
pip install bertopic
# Out:
# Collecting bertopic
#   Downloading bertopic-0.9.4-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 2.7 MB/s
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (5.5.0)
# Collecting hdbscan>=0.8.27
#   Downloading hdbscan-0.8.28.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 8.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.0.2)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.21.5)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (4.63.0)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.3.5)
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.2.tar.gz (86 kB)
#      |████████████████████████████████| 86 kB 7.3 MB/s
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (3.13)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 10.7 MB/s
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic) (0.29.28)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic) (1.4.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (8.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 74.6 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.11.1+cu111)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 70.2 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 8.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.10.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.23.0)
# Collecting pyyaml<6.0
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 65.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (4.11.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.11.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 67.4 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 82.4 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.7)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic) (0.51.2)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.6.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 72.8 MB/s
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2021.10.8)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (PEP 517) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330799 sha256=ca7e15a442a8e14e6af24cb1ef00e78ee2ddd850cd1d79e6cedd68635947b084
#   Stored in directory: /root/.cache/pip/wheels/6e/7a/5e/259ccc841c085fc41b99ef4a71e896b62f5161f2bc8a14c97a
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=5cd962eb9157a9e60c49d553901584ad158c59b1f8cf238ec4fd67fda42a2bda
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.2-py3-none-any.whl size=82708 sha256=1499e4089e7480941c135977ab5c42fe1c1dd265dc576ea187e349bac4322d75
#   Stored in directory: /root/.cache/pip/wheels/84/1b/c6/aaf68a748122632967cef4dffef68224eb16798b6793257d82
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.6-py3-none-any.whl size=53943 sha256=7fcff315e115e0b5efecb8cec6d9c23f0c84c1424dd761ceb94b3dfd5d1e9755
#   Stored in directory: /root/.cache/pip/wheels/03/f1/56/f80d72741e400345b5a5b50ec3d929aca581bf45e0225d5c50
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, pynndescent, umap-learn, sentence-transformers, hdbscan, bertopic
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed bertopic-0.9.4 hdbscan-0.8.28 huggingface-hub-0.5.1 pynndescent-0.5.6 pyyaml-5.4.1 sacremoses-0.0.49 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.11.6 transformers-4.18.0 umap-learn-0.5.2

# %%
# extracting topics and generting probabilities

from bertopic import BERTopic
import pandas as pd 
import numpy as np
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups
 
docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/numba/np/ufunc/parallel.py:363: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   warnings.warn(problem)

# %%
# access the frequent topics that were generated
# -1 refers to all outliers and should typically be ignored

topic_model.get_topic_info()
# Out:
#      Topic  Count                                              Name
# 0       -1   7025                                  -1_to_the_is_and
# 1        0   1827                              0_game_team_games_he
# 2        1    591                     1_key_clipper_encryption_chip
# 3        2    525                              2_ites_cheek_yep_huh
# 4        3    463                        3_israel_israeli_jews_arab
# ..     ...    ...                                               ...
# 229    228     10                    228_68070_motorola_68010_68040
# 230    229     10                229_sound_soundbase_stereo_channel
# 231    230     10  230_manhattan_bobbeviceicotekcom_beauchaine_sank
# 232    231     10                     231_fat_weight_insulin_muscle
# 233    232     10                          232_ear_wax_ears_syringe
#
# [234 rows x 3 columns]

# %%
# most frequent topic that was generated, topic 0

topic_model.get_topic(0)
# Out:
# [('game', 0.010108389225147882),
#  ('team', 0.008831490076270147),
#  ('games', 0.007043755775980492),
#  ('he', 0.0067277959256621155),
#  ('players', 0.006206522524973441),
#  ('season', 0.006138933697557294),
#  ('hockey', 0.00601929992299583),
#  ('play', 0.0056584316354696615),
#  ('25', 0.005518971113407293),
#  ('year', 0.005475923799531879)]

# %%
# Visualize Topics

topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fb9fca2a-ae83-4a53-add2-4b4f311240eb" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb9fca2a-ae83-4a53-add2-4b4f311240eb")) {                    Plotly.newPlot(                        "fb9fca2a-ae83-4a53-add2-4b4f311240eb",                        [{"customdata":[[0,"game | team | games | he | players",1827],[1,"key | clipper | encryption | chip | keys",591],[2,"ites | cheek | yep | huh | silly",525],[3,"israel | israeli | jews | arab | jewish",463],[4,"space | launch | station | shuttle | nasa",178],[5,"amp | audio | stereo | condition | asking",176],[6,"car | cars | mustang | ford | engine",169],[7,"printer | print | deskjet | hp | ink",148],[8,"bike | bikes | miles | motorcycle | honda",138],[9,"atheists | god | atheism | atheist | argument",135],[10,"health | tobacco | cesarean | smokeless | malaria",124],[11,"drive | drives | disk | bios | controller",121],[12,"doctor | cancer | patients | medical | disease",116],[13,"gun | guns | deaths | crime | firearms",106],[14,"window | widget | application | event | expose",104],[15,"armenian | turkish | armenians | genocide | turkey",102],[16,"3d | contact | machines | comments | graphics",98],[17,"fire | fbi | started | bds | gas",96],[18,"ham | radio | interference | antenna | rf",96],[19,"monitor | monitors | vga | horizontal | nec",87],[20,"islam | quran | islamic | rushdie | muslims",86],[21,"ted | post | you | posts | teel",86],[22,"smiley | flame | bolick | maddi | hausmann",85],[23,"simms | simm | vram | ram | meg",84],[24,"serbs | muslims | stephanopoulos | mr | bosnia",83],[25,"men | sex | kinsey | homosexual | gay",82],[26,"pain | migraine | diet | cancer | drug",80],[27,"gif | format | files | program | menu",76],[28,"mbytes | windows | dos | ms | mouse",76],[29,"modem | modems | fax | courier | v32bis",76],[30,"games | joystick | sega | game | arcade",75],[31,"scripture | jesus | books | bible | canon",74],[32,"db | mov | windows | memory | blbh",73],[33,"symbol | error | undefined | libxmulibxmuso | doug",71],[34,"pom | cds | dos | cd | sale",69],[35,"homosexuality | homosexual | homosexuals | sex | sin",68],[36,"windows | os2 | nt | apps | dos",68],[37,"tax | taxes | income | deficit | vat",66],[38,"polygon | xxxx | algorithm | edge | polygons",64],[39,"msg | food | chinese | foods | glutamate",64],[40,"drivers | card | diamond | driver | windows",64],[41,"meg | drive | ram | sale | serial",60],[42,"fonts | font | truetype | tt | atm",60],[43,"scsi | scsi2 | scsi1 | ide | controller",59],[44,"sky | advertising | billboard | billboards | space",59],[45,"diesel | diesels | fuel | emissions | oil",56],[46,"wave | bike | ride | bikers | harley",54],[47,"vitamin | candida | retinol | yeast | infection",54],[48,"motherboard | ram | bios | mb | monitor",53],[49,"batf | warrant | raid | fbi | assault",53],[50,"paint | wax | plastic | scratches | car",51],[51,"adl | bullock | fbi | gerard | reno",51],[52,"were | armenians | they | azerbaijan | her",49],[53,"militia | amendment | arms | bear | right",48],[54,"mary | her | she | bernadette | sin",48],[55,"copy | protection | program | backup | disk",48],[56,"hell | eternal | god | jesus | heaven",47],[57,"radar | detector | detectors | ka | traffic",47],[58,"deleted | stuff | 4084283553 | centigram | madhausnetcomcom",47],[59,"science | methodology | scientific | empirical | theory",46],[60,"koresh | batf | fbi | koreshs | children",46],[61,"hst | reboost | mission | shuttle | orbit",45],[62,"cop | ticket | drunk | driving | roads",43],[63,"mouse | driver | mice | ball | problem",43],[64,"greek | greece | turkish | greeks | turks",42],[65,"clutch | shift | gear | transmission | shifting",41],[66,"jehovah | elohim | lord | mormon | mc ...

# %%
topic_model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="07ab1040-90f3-4f00-8384-b001adc928a6" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07ab1040-90f3-4f00-8384-b001adc928a6")) {                    Plotly.newPlot(                        "07ab1040-90f3-4f00-8384-b001adc928a6",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.006206522524973441,0.0067277959256621155,0.007043755775980492,0.008831490076270147,0.010108389225147882],"y":["players  ","he  ","games  ","team  ","game  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.00965665657541579,0.011831537247383967,0.012043946230697137,0.012625793836167002,0.01391256140184166],"y":["keys  ","chip  ","encryption  ","clipper  ","key  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.23426306739846128,0.2519023207594518,0.2805906686946399,0.3787389232935781,0.4067087136068952],"y":["silly  ","huh  ","yep  ","cheek  ","ites  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.00826486665693168,0.01047362978469665,0.011251273442628074,0.013844531704284267,0.01844207747263342],"y":["jewish  ","arab  ","jews  ","israeli  ","israel  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.008001554635653097,0.008171630708089149,0.009045285285124978,0.01588822819097088,0.019379957787278353],"y":["nasa  ","shuttle  ","station  ","launch  ","space  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.012457647449197765,0.012990314780462111,0.01338359950792511,0.014305807979270294,0.01821643862007854],"y":["asking  ","condition  ","stereo  ","audio  ","amp  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010693304136634732,0.012952362578065674,0.013620685686055557,0.014381820180604538,0.020907586646787487],"y":["engine  ","ford  ","mustang  ","cars  ","car  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.019306435455985982,0.0207830213259743,0.021716281251829457,0.024724599457868302,0.04890601660268562],"y":["ink  ","hp  ","deskjet  ","print  ","printer  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"# ...

# %%
# Dynamic Topic Modeling (DTM) is a collection of techniques aimed at analyzing the evolution of topics over time. 
# These methods allow you to understand how a topic is represented over time.
# Here, we will be using all of Donald Trump's tweet to see how he talked over certain topics over time:

import re
import pandas as pd

trump = pd.read_csv('https://drive.google.com/uc?export=download&id=1xRKHaP-QwACMydlDnyFPEaFdtskJuBa6')
trump.text = trump.apply(lambda row: re.sub(r"http\S+", "", row.text).lower(), 1)
trump.text = trump.apply(lambda row: " ".join(filter(lambda x:x[0]!="@", row.text.split())), 1)
trump.text = trump.apply(lambda row: " ".join(re.sub("[^a-zA-Z]+", " ", row.text).split()), 1)
trump = trump.loc[(trump.isRetweet == "f") & (trump.text != ""), :]
timestamps = trump.date.to_list()
tweets = trump.text.to_list()

# %%
# Extract the global topic representations by creating and training a BERTopic model

topic_model = BERTopic(verbose=True)
topics, probs = topic_model.fit_transform(tweets)
# Out:
# Batches:   0%|          | 0/1418 [00:00<?, ?it/s]
# 2022-04-07 17:44:09,181 - BERTopic - Transformed documents to Embeddings
# 2022-04-07 17:44:45,821 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-07 17:44:49,106 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
# From these topics generate the topic representations at each timestamp for each topic
# by calling topics_over_time and pass in his tweets, the corresponding timestamps, and the related topics

topics_over_time = topic_model.topics_over_time(tweets, topics, timestamps, nr_bins=20)
# Out:
# 20it [00:09,  2.07it/s]

# %%
# Visualize the topics by calling visualize_topics_over_time()

topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=6)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0aaea0e5-62de-4a62-991c-184431e70eae" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0aaea0e5-62de-4a62-991c-184431e70eae")) {                    Plotly.newPlot(                        "0aaea0e5-62de-4a62-991c-184431e70eae",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: execute, imagination, randal, pinkett, utilize","<b>Topic 0</b><br>Words: shouldtrumprun, regarding, difficult, fans, check","<b>Topic 0</b><br>Words: businesspeople, vendetta, considers, madoff, russa","<b>Topic 0</b><br>Words: ricksantorum, recast, yitzhak, invoking, shamir","<b>Topic 0</b><br>Words: run, mr, president, please, thanks","<b>Topic 0</b><br>Words: run, president, needs, mr, please","<b>Topic 0</b><br>Words: run, president, please, mr, needs","<b>Topic 0</b><br>Words: run, please, president, mr, donald","<b>Topic 0</b><br>Words: run, president, mr, please, needs","<b>Topic 0</b><br>Words: trump, donald, president, run, need","<b>Topic 0</b><br>Words: crookedhillary, elect, defeat, president, mr","<b>Topic 0</b><br>Words: manage, executives, ronald, picture, reagan","<b>Topic 0</b><br>Words: retaking, calif, accidents, rust, cr","<b>Topic 0</b><br>Words: journeyed, tatters, triumphs, drawing, sophisticated","<b>Topic 0</b><br>Words: indicators, dream, chaffetz, barrack, overseas","<b>Topic 0</b><br>Words: rt, harry, russiansin, populist, whatley","<b>Topic 0</b><br>Words: amash, sabato, griff, outmastered, objectively","<b>Topic 0</b><br>Words: burn, insurrection, sedition, rubin, herschel"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_run_president_please_mr","x":["2009-04-30T12:30:07.596999","2011-02-03T19:37:55.449999","2011-09-05T03:52:25.600000","2012-04-05T12:06:55.750000","2012-11-04T20:21:25.900000","2013-06-06T04:35:56.049999","2014-01-05T12:50:26.200000","2014-08-06T21:04:56.350000","2015-03-08T05:19:26.500000","2015-10-07T13:33:56.649999","2016-05-07T21:48:26.800000","2016-12-07T06:02:56.950000","2017-07-08T14:17:27.100000","2018-02-06T22:31:57.249999","2018-09-08T06:46:27.400000","2019-04-09T15:00:57.550000","2019-11-08T23:15:27.700000","2020-06-09T07:29:57.849999"],"y":[9,2,11,15,133,294,437,723,908,211,61,2,4,5,12,14,8,13],"type":"scatter"},{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: begun, schedule, ahead, international, scotland","<b>Topic 2</b><br>Words: golf, tngc, scotland, course, channel","<b>Topic 2</b><br>Words: golf, westchester, channel, club, fabulous","<b>Topic 2</b><br>Words: golf, channel, fabulous, course, interns","<b>Topic 2</b><br>Words: golf, invitational, club, benefiting, jude","<b>Topic 2</b><br>Words: golf, scotland, course, links, international","<b>Topic 2</b><br>Words: golf, course, scotland, club, links","<b>Topic 2</b><br>Words: golf, course, scotland, links, pga","<b>Topic 2</b><br>Words: golf, course, scotland, turnberry, courses","<b>Topic 2</b><br>Words: golf, course, scotland, turnberry, club","<b>Topic 2</b><br>Words: golf, course, turnberry, scotland, ferry","<b>Topic 2</b><br>Words: bandon, turnberry, golf, commercials, duel","<b>Topic 2</b><br>Words: turnberry, scotland, opening, course, ailsa","<b>Topic 2</b><br>Words: covfefe, meaning, figure, enjoy, true","<b>Topic 2</b><br>Words: dustin, woods, jupiter, golf, johnson","<b>Topic 2</b><br>Words: golf, brooks, masters, turnberry, tiger","<b>Topic 2</b><br>Words: dustin, furthers, golfer, pga, tour","<b>Topic 2</b><br>Words: gary, golf, turnberry, woodland, overnight","<b>Topic 2</b><br>Words: golf, played, exercise, constantly, representatives","<b>Topic 2</b><br>Words: golf, dustin, exercise, course, goyafoods"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"2_golf_course_scotland_turn ...
